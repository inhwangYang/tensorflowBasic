# %%
import tensorflow as tf

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/",one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
print(tf.convert_to_tensor(mnist.train.images).get_shape())
print(tf.convert_to_tensor(mnist.train.labels).get_shape())
# Out:
# (55000, 784)
# (55000, 10)

# %%
x = tf.placeholder("float",[None,784])
w = tf.Variable(tf.zeros([784,10]))
b = tf.Variable(tf.zeros([10]))



y = tf.nn.softmax(tf.matmul(x,w)+b)

y_ = tf.placeholder("float",[None,10])

cross_entropy = -tf.reduce_sum(y_*tf.log(y))

train_step = tf.train.GradientDescentOptimizer(0.01).minimize(cross_entropy)

sess = tf.Session()

sess.run(tf.global_variables_initializer())

for i in range(1000):
    batch_xs, batch_ys = mnist.train.next_batch(100)
    sess.run(train_step, feed_dict={x:batch_xs, y_:batch_ys})
    
    correct_prediction =  tf.equal(tf.argmax(y,1), tf.argmax(y_,1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction,"float"))
    sess.run(accuracy, feed_dict={x:mnist.test.images, y_:mnist.test.labels})
    print(accuracy)
# Out:
# Tensor("Mean:0", shape=(), dtype=float32)
# Tensor("Mean_1:0", shape=(), dtype=float32)
# Tensor("Mean_2:0", shape=(), dtype=float32)
# Tensor("Mean_3:0", shape=(), dtype=float32)
# Tensor("Mean_4:0", shape=(), dtype=float32)
# Tensor("Mean_5:0", shape=(), dtype=float32)
# Tensor("Mean_6:0", shape=(), dtype=float32)
# Tensor("Mean_7:0", shape=(), dtype=float32)
# Tensor("Mean_8:0", shape=(), dtype=float32)
# Tensor("Mean_9:0", shape=(), dtype=float32)
# Tensor("Mean_10:0", shape=(), dtype=float32)
# Tensor("Mean_11:0", shape=(), dtype=float32)
# Tensor("Mean_12:0", shape=(), dtype=float32)
# Tensor("Mean_13:0", shape=(), dtype=float32)
# Tensor("Mean_14:0", shape=(), dtype=float32)
# Tensor("Mean_15:0", shape=(), dtype=float32)
# Tensor("Mean_16:0", shape=(), dtype=float32)
# Tensor("Mean_17:0", shape=(), dtype=float32)
# Tensor("Mean_18:0", shape=(), dtype=float32)
# Tensor("Mean_19:0", shape=(), dtype=float32)
# Tensor("Mean_20:0", shape=(), dtype=float32)
# Tensor("Mean_21:0", shape=(), dtype=float32)
# Tensor("Mean_22:0", shape=(), dtype=float32)
# Tensor("Mean_23:0", shape=(), dtype=float32)
# Tensor("Mean_24:0", shape=(), dtype=float32)
# Tensor("Mean_25:0", shape=(), dtype=float32)
# Tensor("Mean_26:0", shape=(), dtype=float32)
# Tensor("Mean_27:0", shape=(), dtype=float32)
# Tensor("Mean_28:0", shape=(), dtype=float32)
# Tensor("Mean_29:0", shape=(), dtype=float32)
# Tensor("Mean_30:0", shape=(), dtype=float32)
# Tensor("Mean_31:0", shape=(), dtype=float32)
# Tensor("Mean_32:0", shape=(), dtype=float32)
# Tensor("Mean_33:0", shape=(), dtype=float32)
# Tensor("Mean_34:0", shape=(), dtype=float32)
# Tensor("Mean_35:0", shape=(), dtype=float32)
# Tensor("Mean_36:0", shape=(), dtype=float32)
# Tensor("Mean_37:0", shape=(), dtype=float32)
# Tensor("Mean_38:0", shape=(), dtype=float32)
# Tensor("Mean_39:0", shape=(), dtype=float32)
# Tensor("Mean_40:0", shape=(), dtype=float32)
# Tensor("Mean_41:0", shape=(), dtype=float32)
# Tensor("Mean_42:0", shape=(), dtype=float32)
# Tensor("Mean_43:0", shape=(), dtype=float32)
# Tensor("Mean_44:0", shape=(), dtype=float32)
# Tensor("Mean_45:0", shape=(), dtype=float32)
# Tensor("Mean_46:0", shape=(), dtype=float32)
# Tensor("Mean_47:0", shape=(), dtype=float32)
# Tensor("Mean_48:0", shape=(), dtype=float32)
# Tensor("Mean_49:0", shape=(), dtype=float32)
# Tensor("Mean_50:0", shape=(), dtype=float32)
# Tensor("Mean_51:0", shape=(), dtype=float32)
# Tensor("Mean_52:0", shape=(), dtype=float32)
# Tensor("Mean_53:0", shape=(), dtype=float32)
# Tensor("Mean_54:0", shape=(), dtype=float32)
# Tensor("Mean_55:0", shape=(), dtype=float32)
# Tensor("Mean_56:0", shape=(), dtype=float32)
# Tensor("Mean_57:0", shape=(), dtype=float32)
# Tensor("Mean_58:0", shape=(), dtype=float32)
# Tensor("Mean_59:0", shape=(), dtype=float32)
# Tensor("Mean_60:0", shape=(), dtype=float32)
# Tensor("Mean_61:0", shape=(), dtype=float32)
# Tensor("Mean_62:0", shape=(), dtype=float32)
# Tensor("Mean_63:0", shape=(), dtype=float32)
# Tensor("Mean_64:0", shape=(), dtype=float32)
# Tensor("Mean_65:0", shape=(), dtype=float32)
# Tensor("Mean_66:0", shape=(), dtype=float32)
# Tensor("Mean_67:0", shape=(), dtype=float32)
# Tensor("Mean_68:0", shape=(), dtype=float32)
# Tensor("Mean_69:0", shape=(), dtype=float32)
# Tensor("Mean_70:0", shape=(), dtype=float32)
# Tensor("Mean_71:0", shape=(), dtype=float32)
# Tensor("Mean_72:0", shape=(), dtype=float32)
# Tensor("Mean_73:0", shape=(), dtype=float32)
# Tensor("Mean_74:0", shape=(), dtype=float32)
# Tensor("Mean_75:0", shape=(), dtype=float32)
# Tensor("Mean_76:0", shape=(), dtype=float32)
# Tensor("Mean_77:0", shape=(), dtype=float32)
# Tensor("Mean_78:0", shape=(), dtype=float32)
# Tensor("Mean_79:0", shape=(), dtype=float32)
# Tensor("Mean_80:0", shape=(), dtype=float32)
# Tensor("Mean_81:0", shape=(), dtype=float32)
# Tensor("Mean_82:0", shape=(), dtype=float32)
# Tensor("Mean_83:0", shape=(), dtype=float32)
# Tensor("Mean_84:0", shape=(), dtype=float32)
# Tensor("Mean_85:0", shape=(), dtype=float32)
# Tensor("Mean_86:0", shape=(), dtype=float32)
# Tensor("Mean_87:0", shape=(), dtype=float32)
# Tensor("Mean_88:0", shape=(), dtype=float32)
# Tensor("Mean_89:0", shape=(), dtype=float32)
# Tensor("Mean_90:0", shape=(), dtype=float32)
# Tensor("Mean_91:0", shape=(), dtype=float32)
# Tensor("Mean_92:0", shape=(), dtype=float32)
# Tensor("Mean_93:0", shape=(), dtype=float32)
# Tensor("Mean_94:0", shape=(), dtype=float32)
# Tensor("Mean_95:0", shape=(), dtype=float32)
# Tensor("Mean_96:0", shape=(), dtype=float32)
# Tensor("Mean_97:0", shape=(), dtype=float32)
# Tensor("Mean_98:0", shape=(), dtype=float32)
# Tensor("Mean_99:0", shape=(), dtype=float32)
# Tensor("Mean_100:0", shape=(), dtype=float32)
# Tensor("Mean_101:0", shape=(), dtype=float32)
# Tensor("Mean_102:0", shape=(), dtype=float32)
# Tensor("Mean_103:0", shape=(), dtype=float32)
# Tensor("Mean_104:0", shape=(), dtype=float32)
# Tensor("Mean_105:0", shape=(), dtype=float32)
# Tensor("Mean_106:0", shape=(), dtype=float32)
# Tensor("Mean_107:0", shape=(), dtype=float32)
# Tensor("Mean_108:0", shape=(), dtype=float32)
# Tensor("Mean_109:0", shape=(), dtype=float32)
# Tensor("Mean_110:0", shape=(), dtype=float32)
# Tensor("Mean_111:0", shape=(), dtype=float32)
# Tensor("Mean_112:0", shape=(), dtype=float32)
# Tensor("Mean_113:0", shape=(), dtype=float32)
# Tensor("Mean_114:0", shape=(), dtype=float32)
# Tensor("Mean_115:0", shape=(), dtype=float32)
# Tensor("Mean_116:0", shape=(), dtype=float32)
# Tensor("Mean_117:0", shape=(), dtype=float32)
# Tensor("Mean_118:0", shape=(), dtype=float32)
# Tensor("Mean_119:0", shape=(), dtype=float32)
# Tensor("Mean_120:0", shape=(), dtype=float32)
# Tensor("Mean_121:0", shape=(), dtype=float32)
# Tensor("Mean_122:0", shape=(), dtype=float32)
# Tensor("Mean_123:0", shape=(), dtype=float32)
# Tensor("Mean_124:0", shape=(), dtype=float32)
# Tensor("Mean_125:0", shape=(), dtype=float32)
# Tensor("Mean_126:0", shape=(), dtype=float32)
# Tensor("Mean_127:0", shape=(), dtype=float32)
# Tensor("Mean_128:0", shape=(), dtype=float32)
# Tensor("Mean_129:0", shape=(), dtype=float32)
# Tensor("Mean_130:0", shape=(), dtype=float32)
# Tensor("Mean_131:0", shape=(), dtype=float32)
# Tensor("Mean_132:0", shape=(), dtype=float32)
# Tensor("Mean_133:0", shape=(), dtype=float32)
# Tensor("Mean_134:0", shape=(), dtype=float32)
# Tensor("Mean_135:0", shape=(), dtype=float32)
# Tensor("Mean_136:0", shape=(), dtype=float32)
# Tensor("Mean_137:0", shape=(), dtype=float32)
# Tensor("Mean_138:0", shape=(), dtype=float32)
# Tensor("Mean_139:0", shape=(), dtype=float32)
# Tensor("Mean_140:0", shape=(), dtype=float32)
# Tensor("Mean_141:0", shape=(), dtype=float32)
# Tensor("Mean_142:0", shape=(), dtype=float32)
# Tensor("Mean_143:0", shape=(), dtype=float32)
# Tensor("Mean_144:0", shape=(), dtype=float32)
# Tensor("Mean_145:0", shape=(), dtype=float32)
# Tensor("Mean_146:0", shape=(), dtype=float32)
# Tensor("Mean_147:0", shape=(), dtype=float32)
# Tensor("Mean_148:0", shape=(), dtype=float32)
# Tensor("Mean_149:0", shape=(), dtype=float32)
# Tensor("Mean_150:0", shape=(), dtype=float32)
# Tensor("Mean_151:0", shape=(), dtype=float32)
# Tensor("Mean_152:0", shape=(), dtype=float32)
# Tensor("Mean_153:0", shape=(), dtype=float32)
# Tensor("Mean_154:0", shape=(), dtype=float32)
# Tensor("Mean_155:0", shape=(), dtype=float32)
# Tensor("Mean_156:0", shape=(), dtype=float32)
# Tensor("Mean_157:0", shape=(), dtype=float32)
# Tensor("Mean_158:0", shape=(), dtype=float32)
# Tensor("Mean_159:0", shape=(), dtype=float32)
# Tensor("Mean_160:0", shape=(), dtype=float32)
# Tensor("Mean_161:0", shape=(), dtype=float32)
# Tensor("Mean_162:0", shape=(), dtype=float32)
# Tensor("Mean_163:0", shape=(), dtype=float32)
# Tensor("Mean_164:0", shape=(), dtype=float32)
# Tensor("Mean_165:0", shape=(), dtype=float32)
# Tensor("Mean_166:0", shape=(), dtype=float32)
# Tensor("Mean_167:0", shape=(), dtype=float32)
# Tensor("Mean_168:0", shape=(), dtype=float32)
# Tensor("Mean_169:0", shape=(), dtype=float32)
# Tensor("Mean_170:0", shape=(), dtype=float32)
# Tensor("Mean_171:0", shape=(), dtype=float32)
# Tensor("Mean_172:0", shape=(), dtype=float32)
# Tensor("Mean_173:0", shape=(), dtype=float32)
# Tensor("Mean_174:0", shape=(), dtype=float32)
# Tensor("Mean_175:0", shape=(), dtype=float32)
# Tensor("Mean_176:0", shape=(), dtype=float32)
# Tensor("Mean_177:0", shape=(), dtype=float32)
# Tensor("Mean_178:0", shape=(), dtype=float32)
# Tensor("Mean_179:0", shape=(), dtype=float32)
# Tensor("Mean_180:0", shape=(), dtype=float32)
# Tensor("Mean_181:0", shape=(), dtype=float32)
# Tensor("Mean_182:0", shape=(), dtype=float32)
# Tensor("Mean_183:0", shape=(), dtype=float32)
# Tensor("Mean_184:0", shape=(), dtype=float32)
# Tensor("Mean_185:0", shape=(), dtype=float32)
# Tensor("Mean_186:0", shape=(), dtype=float32)
# Tensor("Mean_187:0", shape=(), dtype=float32)
# Tensor("Mean_188:0", shape=(), dtype=float32)
# Tensor("Mean_189:0", shape=(), dtype=float32)
# Tensor("Mean_190:0", shape=(), dtype=float32)
# Tensor("Mean_191:0", shape=(), dtype=float32)
# Tensor("Mean_192:0", shape=(), dtype=float32)
# Tensor("Mean_193:0", shape=(), dtype=float32)
# Tensor("Mean_194:0", shape=(), dtype=float32)
# Tensor("Mean_195:0", shape=(), dtype=float32)
# Tensor("Mean_196:0", shape=(), dtype=float32)
# Tensor("Mean_197:0", shape=(), dtype=float32)
# Tensor("Mean_198:0", shape=(), dtype=float32)
# Tensor("Mean_199:0", shape=(), dtype=float32)
# Tensor("Mean_200:0", shape=(), dtype=float32)
# Tensor("Mean_201:0", shape=(), dtype=float32)
# Tensor("Mean_202:0", shape=(), dtype=float32)
# Tensor("Mean_203:0", shape=(), dtype=float32)
# Tensor("Mean_204:0", shape=(), dtype=float32)
# Tensor("Mean_205:0", shape=(), dtype=float32)
# Tensor("Mean_206:0", shape=(), dtype=float32)
# Tensor("Mean_207:0", shape=(), dtype=float32)
# Tensor("Mean_208:0", shape=(), dtype=float32)
# Tensor("Mean_209:0", shape=(), dtype=float32)
# Tensor("Mean_210:0", shape=(), dtype=float32)
# Tensor("Mean_211:0", shape=(), dtype=float32)
# Tensor("Mean_212:0", shape=(), dtype=float32)
# Tensor("Mean_213:0", shape=(), dtype=float32)
# Tensor("Mean_214:0", shape=(), dtype=float32)
# Tensor("Mean_215:0", shape=(), dtype=float32)
# Tensor("Mean_216:0", shape=(), dtype=float32)
# Tensor("Mean_217:0", shape=(), dtype=float32)
# Tensor("Mean_218:0", shape=(), dtype=float32)
# Tensor("Mean_219:0", shape=(), dtype=float32)
# Tensor("Mean_220:0", shape=(), dtype=float32)
# Tensor("Mean_221:0", shape=(), dtype=float32)
# Tensor("Mean_222:0", shape=(), dtype=float32)
# Tensor("Mean_223:0", shape=(), dtype=float32)
# Tensor("Mean_224:0", shape=(), dtype=float32)
# Tensor("Mean_225:0", shape=(), dtype=float32)
# Tensor("Mean_226:0", shape=(), dtype=float32)
# Tensor("Mean_227:0", shape=(), dtype=float32)
# Tensor("Mean_228:0", shape=(), dtype=float32)
# Tensor("Mean_229:0", shape=(), dtype=float32)
# Tensor("Mean_230:0", shape=(), dtype=float32)
# Tensor("Mean_231:0", shape=(), dtype=float32)
# Tensor("Mean_232:0", shape=(), dtype=float32)
# Tensor("Mean_233:0", shape=(), dtype=float32)
# Tensor("Mean_234:0", shape=(), dtype=float32)
# Tensor("Mean_235:0", shape=(), dtype=float32)
# Tensor("Mean_236:0", shape=(), dtype=float32)
# Tensor("Mean_237:0", shape=(), dtype=float32)
# Tensor("Mean_238:0", shape=(), dtype=float32)
# Tensor("Mean_239:0", shape=(), dtype=float32)
# Tensor("Mean_240:0", shape=(), dtype=float32)
# Tensor("Mean_241:0", shape=(), dtype=float32)
# Tensor("Mean_242:0", shape=(), dtype=float32)
# Tensor("Mean_243:0", shape=(), dtype=float32)
# Tensor("Mean_244:0", shape=(), dtype=float32)
# Tensor("Mean_245:0", shape=(), dtype=float32)
# Tensor("Mean_246:0", shape=(), dtype=float32)
# Tensor("Mean_247:0", shape=(), dtype=float32)
# Tensor("Mean_248:0", shape=(), dtype=float32)
# Tensor("Mean_249:0", shape=(), dtype=float32)
# Tensor("Mean_250:0", shape=(), dtype=float32)
# Tensor("Mean_251:0", shape=(), dtype=float32)
# Tensor("Mean_252:0", shape=(), dtype=float32)
# Tensor("Mean_253:0", shape=(), dtype=float32)
# Tensor("Mean_254:0", shape=(), dtype=float32)
# Tensor("Mean_255:0", shape=(), dtype=float32)
# Tensor("Mean_256:0", shape=(), dtype=float32)
# Tensor("Mean_257:0", shape=(), dtype=float32)
# Tensor("Mean_258:0", shape=(), dtype=float32)
# Tensor("Mean_259:0", shape=(), dtype=float32)
# Tensor("Mean_260:0", shape=(), dtype=float32)
# Tensor("Mean_261:0", shape=(), dtype=float32)
# Tensor("Mean_262:0", shape=(), dtype=float32)
# Tensor("Mean_263:0", shape=(), dtype=float32)
# Tensor("Mean_264:0", shape=(), dtype=float32)
# Tensor("Mean_265:0", shape=(), dtype=float32)
# Tensor("Mean_266:0", shape=(), dtype=float32)
# Tensor("Mean_267:0", shape=(), dtype=float32)
# Tensor("Mean_268:0", shape=(), dtype=float32)
# Tensor("Mean_269:0", shape=(), dtype=float32)
# Tensor("Mean_270:0", shape=(), dtype=float32)
# Tensor("Mean_271:0", shape=(), dtype=float32)
# Tensor("Mean_272:0", shape=(), dtype=float32)
# Tensor("Mean_273:0", shape=(), dtype=float32)
# Tensor("Mean_274:0", shape=(), dtype=float32)
# Tensor("Mean_275:0", shape=(), dtype=float32)
# Tensor("Mean_276:0", shape=(), dtype=float32)
# Tensor("Mean_277:0", shape=(), dtype=float32)
# Tensor("Mean_278:0", shape=(), dtype=float32)
# Tensor("Mean_279:0", shape=(), dtype=float32)
# Tensor("Mean_280:0", shape=(), dtype=float32)
# Tensor("Mean_281:0", shape=(), dtype=float32)
# Tensor("Mean_282:0", shape=(), dtype=float32)
# Tensor("Mean_283:0", shape=(), dtype=float32)
# Tensor("Mean_284:0", shape=(), dtype=float32)
# Tensor("Mean_285:0", shape=(), dtype=float32)
# Tensor("Mean_286:0", shape=(), dtype=float32)
# Tensor("Mean_287:0", shape=(), dtype=float32)
# Tensor("Mean_288:0", shape=(), dtype=float32)
# Tensor("Mean_289:0", shape=(), dtype=float32)
# Tensor("Mean_290:0", shape=(), dtype=float32)
# Tensor("Mean_291:0", shape=(), dtype=float32)
# Tensor("Mean_292:0", shape=(), dtype=float32)
# Tensor("Mean_293:0", shape=(), dtype=float32)
# Tensor("Mean_294:0", shape=(), dtype=float32)
# Tensor("Mean_295:0", shape=(), dtype=float32)
# Tensor("Mean_296:0", shape=(), dtype=float32)
# Tensor("Mean_297:0", shape=(), dtype=float32)
# Tensor("Mean_298:0", shape=(), dtype=float32)
# Tensor("Mean_299:0", shape=(), dtype=float32)
# Tensor("Mean_300:0", shape=(), dtype=float32)
# Tensor("Mean_301:0", shape=(), dtype=float32)
# Tensor("Mean_302:0", shape=(), dtype=float32)
# Tensor("Mean_303:0", shape=(), dtype=float32)
# Tensor("Mean_304:0", shape=(), dtype=float32)
# Tensor("Mean_305:0", shape=(), dtype=float32)
# Tensor("Mean_306:0", shape=(), dtype=float32)
# Tensor("Mean_307:0", shape=(), dtype=float32)
# Tensor("Mean_308:0", shape=(), dtype=float32)
# Tensor("Mean_309:0", shape=(), dtype=float32)
# Tensor("Mean_310:0", shape=(), dtype=float32)
# Tensor("Mean_311:0", shape=(), dtype=float32)
# Tensor("Mean_312:0", shape=(), dtype=float32)
# Tensor("Mean_313:0", shape=(), dtype=float32)
# Tensor("Mean_314:0", shape=(), dtype=float32)
# Tensor("Mean_315:0", shape=(), dtype=float32)
# Tensor("Mean_316:0", shape=(), dtype=float32)
# Tensor("Mean_317:0", shape=(), dtype=float32)
# Tensor("Mean_318:0", shape=(), dtype=float32)
# Tensor("Mean_319:0", shape=(), dtype=float32)
# Tensor("Mean_320:0", shape=(), dtype=float32)
# Tensor("Mean_321:0", shape=(), dtype=float32)
# Tensor("Mean_322:0", shape=(), dtype=float32)
# Tensor("Mean_323:0", shape=(), dtype=float32)
# Tensor("Mean_324:0", shape=(), dtype=float32)
# Tensor("Mean_325:0", shape=(), dtype=float32)
# Tensor("Mean_326:0", shape=(), dtype=float32)
# Tensor("Mean_327:0", shape=(), dtype=float32)
# Tensor("Mean_328:0", shape=(), dtype=float32)
# Tensor("Mean_329:0", shape=(), dtype=float32)
# Tensor("Mean_330:0", shape=(), dtype=float32)
# Tensor("Mean_331:0", shape=(), dtype=float32)
# Tensor("Mean_332:0", shape=(), dtype=float32)
# Tensor("Mean_333:0", shape=(), dtype=float32)
# Tensor("Mean_334:0", shape=(), dtype=float32)
# Tensor("Mean_335:0", shape=(), dtype=float32)
# Tensor("Mean_336:0", shape=(), dtype=float32)
# Tensor("Mean_337:0", shape=(), dtype=float32)
# Tensor("Mean_338:0", shape=(), dtype=float32)
# Tensor("Mean_339:0", shape=(), dtype=float32)
# Tensor("Mean_340:0", shape=(), dtype=float32)
# Tensor("Mean_341:0", shape=(), dtype=float32)
# Tensor("Mean_342:0", shape=(), dtype=float32)
# Tensor("Mean_343:0", shape=(), dtype=float32)
# Tensor("Mean_344:0", shape=(), dtype=float32)
# Tensor("Mean_345:0", shape=(), dtype=float32)
# Tensor("Mean_346:0", shape=(), dtype=float32)
# Tensor("Mean_347:0", shape=(), dtype=float32)
# Tensor("Mean_348:0", shape=(), dtype=float32)
# Tensor("Mean_349:0", shape=(), dtype=float32)
# Tensor("Mean_350:0", shape=(), dtype=float32)
# Tensor("Mean_351:0", shape=(), dtype=float32)
# Tensor("Mean_352:0", shape=(), dtype=float32)
# Tensor("Mean_353:0", shape=(), dtype=float32)
# Tensor("Mean_354:0", shape=(), dtype=float32)
# Tensor("Mean_355:0", shape=(), dtype=float32)
# Tensor("Mean_356:0", shape=(), dtype=float32)
# Tensor("Mean_357:0", shape=(), dtype=float32)
# Tensor("Mean_358:0", shape=(), dtype=float32)
# Tensor("Mean_359:0", shape=(), dtype=float32)
# Tensor("Mean_360:0", shape=(), dtype=float32)
# Tensor("Mean_361:0", shape=(), dtype=float32)
# Tensor("Mean_362:0", shape=(), dtype=float32)
# Tensor("Mean_363:0", shape=(), dtype=float32)
# Tensor("Mean_364:0", shape=(), dtype=float32)
# Tensor("Mean_365:0", shape=(), dtype=float32)
# Tensor("Mean_366:0", shape=(), dtype=float32)
# Tensor("Mean_367:0", shape=(), dtype=float32)
# Tensor("Mean_368:0", shape=(), dtype=float32)
# Tensor("Mean_369:0", shape=(), dtype=float32)
# Tensor("Mean_370:0", shape=(), dtype=float32)
# Tensor("Mean_371:0", shape=(), dtype=float32)
# Tensor("Mean_372:0", shape=(), dtype=float32)
# Tensor("Mean_373:0", shape=(), dtype=float32)
# Tensor("Mean_374:0", shape=(), dtype=float32)
# Tensor("Mean_375:0", shape=(), dtype=float32)
# Tensor("Mean_376:0", shape=(), dtype=float32)
# Tensor("Mean_377:0", shape=(), dtype=float32)
# Tensor("Mean_378:0", shape=(), dtype=float32)
# Tensor("Mean_379:0", shape=(), dtype=float32)
# Tensor("Mean_380:0", shape=(), dtype=float32)
# Tensor("Mean_381:0", shape=(), dtype=float32)
# Tensor("Mean_382:0", shape=(), dtype=float32)
# Tensor("Mean_383:0", shape=(), dtype=float32)
# Tensor("Mean_384:0", shape=(), dtype=float32)
# Tensor("Mean_385:0", shape=(), dtype=float32)
# Tensor("Mean_386:0", shape=(), dtype=float32)
# Tensor("Mean_387:0", shape=(), dtype=float32)
# Tensor("Mean_388:0", shape=(), dtype=float32)
# Tensor("Mean_389:0", shape=(), dtype=float32)
# Tensor("Mean_390:0", shape=(), dtype=float32)
# Tensor("Mean_391:0", shape=(), dtype=float32)
# Tensor("Mean_392:0", shape=(), dtype=float32)
# Tensor("Mean_393:0", shape=(), dtype=float32)
# Tensor("Mean_394:0", shape=(), dtype=float32)
# Tensor("Mean_395:0", shape=(), dtype=float32)
# Tensor("Mean_396:0", shape=(), dtype=float32)
# Tensor("Mean_397:0", shape=(), dtype=float32)
# Tensor("Mean_398:0", shape=(), dtype=float32)
# Tensor("Mean_399:0", shape=(), dtype=float32)
# Tensor("Mean_400:0", shape=(), dtype=float32)
# Tensor("Mean_401:0", shape=(), dtype=float32)
# Tensor("Mean_402:0", shape=(), dtype=float32)
# Tensor("Mean_403:0", shape=(), dtype=float32)
# Tensor("Mean_404:0", shape=(), dtype=float32)
# Tensor("Mean_405:0", shape=(), dtype=float32)
# Tensor("Mean_406:0", shape=(), dtype=float32)
# Tensor("Mean_407:0", shape=(), dtype=float32)
# Tensor("Mean_408:0", shape=(), dtype=float32)
# Tensor("Mean_409:0", shape=(), dtype=float32)
# Tensor("Mean_410:0", shape=(), dtype=float32)
# Tensor("Mean_411:0", shape=(), dtype=float32)
# Tensor("Mean_412:0", shape=(), dtype=float32)
# Tensor("Mean_413:0", shape=(), dtype=float32)
# Tensor("Mean_414:0", shape=(), dtype=float32)
# Tensor("Mean_415:0", shape=(), dtype=float32)
# Tensor("Mean_416:0", shape=(), dtype=float32)
# Tensor("Mean_417:0", shape=(), dtype=float32)
# Tensor("Mean_418:0", shape=(), dtype=float32)
# Tensor("Mean_419:0", shape=(), dtype=float32)
# Tensor("Mean_420:0", shape=(), dtype=float32)
# Tensor("Mean_421:0", shape=(), dtype=float32)
# Tensor("Mean_422:0", shape=(), dtype=float32)
# Tensor("Mean_423:0", shape=(), dtype=float32)
# Tensor("Mean_424:0", shape=(), dtype=float32)
# Tensor("Mean_425:0", shape=(), dtype=float32)
# Tensor("Mean_426:0", shape=(), dtype=float32)
# Tensor("Mean_427:0", shape=(), dtype=float32)
# Tensor("Mean_428:0", shape=(), dtype=float32)
# Tensor("Mean_429:0", shape=(), dtype=float32)
# Tensor("Mean_430:0", shape=(), dtype=float32)
# Tensor("Mean_431:0", shape=(), dtype=float32)
# Tensor("Mean_432:0", shape=(), dtype=float32)
# Tensor("Mean_433:0", shape=(), dtype=float32)
# Tensor("Mean_434:0", shape=(), dtype=float32)
# Tensor("Mean_435:0", shape=(), dtype=float32)
# Tensor("Mean_436:0", shape=(), dtype=float32)
# Tensor("Mean_437:0", shape=(), dtype=float32)
# Tensor("Mean_438:0", shape=(), dtype=float32)
# Tensor("Mean_439:0", shape=(), dtype=float32)
# Tensor("Mean_440:0", shape=(), dtype=float32)
# Tensor("Mean_441:0", shape=(), dtype=float32)
# Tensor("Mean_442:0", shape=(), dtype=float32)
# Tensor("Mean_443:0", shape=(), dtype=float32)
# Tensor("Mean_444:0", shape=(), dtype=float32)
# Tensor("Mean_445:0", shape=(), dtype=float32)
# Tensor("Mean_446:0", shape=(), dtype=float32)
# Tensor("Mean_447:0", shape=(), dtype=float32)
# Tensor("Mean_448:0", shape=(), dtype=float32)
# Tensor("Mean_449:0", shape=(), dtype=float32)
# Tensor("Mean_450:0", shape=(), dtype=float32)
# Tensor("Mean_451:0", shape=(), dtype=float32)
# Tensor("Mean_452:0", shape=(), dtype=float32)
# Tensor("Mean_453:0", shape=(), dtype=float32)
# Tensor("Mean_454:0", shape=(), dtype=float32)
# Tensor("Mean_455:0", shape=(), dtype=float32)
# Tensor("Mean_456:0", shape=(), dtype=float32)
# Tensor("Mean_457:0", shape=(), dtype=float32)
# Tensor("Mean_458:0", shape=(), dtype=float32)
# Tensor("Mean_459:0", shape=(), dtype=float32)
# Tensor("Mean_460:0", shape=(), dtype=float32)
# Tensor("Mean_461:0", shape=(), dtype=float32)
# Tensor("Mean_462:0", shape=(), dtype=float32)
# Tensor("Mean_463:0", shape=(), dtype=float32)
# Tensor("Mean_464:0", shape=(), dtype=float32)
# Tensor("Mean_465:0", shape=(), dtype=float32)
# Tensor("Mean_466:0", shape=(), dtype=float32)
# Tensor("Mean_467:0", shape=(), dtype=float32)
# Tensor("Mean_468:0", shape=(), dtype=float32)
# Tensor("Mean_469:0", shape=(), dtype=float32)
# Tensor("Mean_470:0", shape=(), dtype=float32)
# Tensor("Mean_471:0", shape=(), dtype=float32)
# Tensor("Mean_472:0", shape=(), dtype=float32)
# Tensor("Mean_473:0", shape=(), dtype=float32)
# Tensor("Mean_474:0", shape=(), dtype=float32)
# Tensor("Mean_475:0", shape=(), dtype=float32)
# Tensor("Mean_476:0", shape=(), dtype=float32)
# Tensor("Mean_477:0", shape=(), dtype=float32)
# Tensor("Mean_478:0", shape=(), dtype=float32)
# Tensor("Mean_479:0", shape=(), dtype=float32)
# Tensor("Mean_480:0", shape=(), dtype=float32)
# Tensor("Mean_481:0", shape=(), dtype=float32)
# Tensor("Mean_482:0", shape=(), dtype=float32)
# Tensor("Mean_483:0", shape=(), dtype=float32)
# Tensor("Mean_484:0", shape=(), dtype=float32)
# Tensor("Mean_485:0", shape=(), dtype=float32)
# Tensor("Mean_486:0", shape=(), dtype=float32)
# Tensor("Mean_487:0", shape=(), dtype=float32)
# Tensor("Mean_488:0", shape=(), dtype=float32)
# Tensor("Mean_489:0", shape=(), dtype=float32)
# Tensor("Mean_490:0", shape=(), dtype=float32)
# Tensor("Mean_491:0", shape=(), dtype=float32)
# Tensor("Mean_492:0", shape=(), dtype=float32)
# Tensor("Mean_493:0", shape=(), dtype=float32)
# Tensor("Mean_494:0", shape=(), dtype=float32)
# Tensor("Mean_495:0", shape=(), dtype=float32)
# Tensor("Mean_496:0", shape=(), dtype=float32)
# Tensor("Mean_497:0", shape=(), dtype=float32)
# Tensor("Mean_498:0", shape=(), dtype=float32)
# Tensor("Mean_499:0", shape=(), dtype=float32)
# Tensor("Mean_500:0", shape=(), dtype=float32)
# Tensor("Mean_501:0", shape=(), dtype=float32)
# Tensor("Mean_502:0", shape=(), dtype=float32)
# Tensor("Mean_503:0", shape=(), dtype=float32)
# Tensor("Mean_504:0", shape=(), dtype=float32)
# Tensor("Mean_505:0", shape=(), dtype=float32)
# Tensor("Mean_506:0", shape=(), dtype=float32)
# Tensor("Mean_507:0", shape=(), dtype=float32)
# Tensor("Mean_508:0", shape=(), dtype=float32)
# Tensor("Mean_509:0", shape=(), dtype=float32)
# Tensor("Mean_510:0", shape=(), dtype=float32)
# Tensor("Mean_511:0", shape=(), dtype=float32)
# Tensor("Mean_512:0", shape=(), dtype=float32)
# Tensor("Mean_513:0", shape=(), dtype=float32)
# Tensor("Mean_514:0", shape=(), dtype=float32)
# Tensor("Mean_515:0", shape=(), dtype=float32)
# Tensor("Mean_516:0", shape=(), dtype=float32)
# Tensor("Mean_517:0", shape=(), dtype=float32)
# Tensor("Mean_518:0", shape=(), dtype=float32)
# Tensor("Mean_519:0", shape=(), dtype=float32)
# Tensor("Mean_520:0", shape=(), dtype=float32)
# Tensor("Mean_521:0", shape=(), dtype=float32)
# Tensor("Mean_522:0", shape=(), dtype=float32)
# Tensor("Mean_523:0", shape=(), dtype=float32)
# Tensor("Mean_524:0", shape=(), dtype=float32)
# Tensor("Mean_525:0", shape=(), dtype=float32)
# Tensor("Mean_526:0", shape=(), dtype=float32)
# Tensor("Mean_527:0", shape=(), dtype=float32)
# Tensor("Mean_528:0", shape=(), dtype=float32)
# Tensor("Mean_529:0", shape=(), dtype=float32)
# Tensor("Mean_530:0", shape=(), dtype=float32)
# Tensor("Mean_531:0", shape=(), dtype=float32)
# Tensor("Mean_532:0", shape=(), dtype=float32)
# Tensor("Mean_533:0", shape=(), dtype=float32)
# Tensor("Mean_534:0", shape=(), dtype=float32)
# Tensor("Mean_535:0", shape=(), dtype=float32)
# Tensor("Mean_536:0", shape=(), dtype=float32)
# Tensor("Mean_537:0", shape=(), dtype=float32)
# Tensor("Mean_538:0", shape=(), dtype=float32)
# Tensor("Mean_539:0", shape=(), dtype=float32)
# Tensor("Mean_540:0", shape=(), dtype=float32)
# Tensor("Mean_541:0", shape=(), dtype=float32)
# Tensor("Mean_542:0", shape=(), dtype=float32)
# Tensor("Mean_543:0", shape=(), dtype=float32)
# Tensor("Mean_544:0", shape=(), dtype=float32)
# Tensor("Mean_545:0", shape=(), dtype=float32)
# Tensor("Mean_546:0", shape=(), dtype=float32)
# Tensor("Mean_547:0", shape=(), dtype=float32)
# Tensor("Mean_548:0", shape=(), dtype=float32)
# Tensor("Mean_549:0", shape=(), dtype=float32)
# Tensor("Mean_550:0", shape=(), dtype=float32)
# Tensor("Mean_551:0", shape=(), dtype=float32)
# Tensor("Mean_552:0", shape=(), dtype=float32)
# Tensor("Mean_553:0", shape=(), dtype=float32)
# Tensor("Mean_554:0", shape=(), dtype=float32)
# Tensor("Mean_555:0", shape=(), dtype=float32)
# Tensor("Mean_556:0", shape=(), dtype=float32)
# Tensor("Mean_557:0", shape=(), dtype=float32)
# Tensor("Mean_558:0", shape=(), dtype=float32)
# Tensor("Mean_559:0", shape=(), dtype=float32)
# Tensor("Mean_560:0", shape=(), dtype=float32)
# Tensor("Mean_561:0", shape=(), dtype=float32)
# Tensor("Mean_562:0", shape=(), dtype=float32)
# Tensor("Mean_563:0", shape=(), dtype=float32)
# Tensor("Mean_564:0", shape=(), dtype=float32)
# Tensor("Mean_565:0", shape=(), dtype=float32)
# Tensor("Mean_566:0", shape=(), dtype=float32)
# Tensor("Mean_567:0", shape=(), dtype=float32)
# Tensor("Mean_568:0", shape=(), dtype=float32)
# Tensor("Mean_569:0", shape=(), dtype=float32)
# Tensor("Mean_570:0", shape=(), dtype=float32)
# Tensor("Mean_571:0", shape=(), dtype=float32)
# Tensor("Mean_572:0", shape=(), dtype=float32)
# Tensor("Mean_573:0", shape=(), dtype=float32)
# Tensor("Mean_574:0", shape=(), dtype=float32)
# Tensor("Mean_575:0", shape=(), dtype=float32)
# Tensor("Mean_576:0", shape=(), dtype=float32)
# Tensor("Mean_577:0", shape=(), dtype=float32)
# Tensor("Mean_578:0", shape=(), dtype=float32)
# Tensor("Mean_579:0", shape=(), dtype=float32)
# Tensor("Mean_580:0", shape=(), dtype=float32)
# Tensor("Mean_581:0", shape=(), dtype=float32)
# Tensor("Mean_582:0", shape=(), dtype=float32)
# Tensor("Mean_583:0", shape=(), dtype=float32)
# Tensor("Mean_584:0", shape=(), dtype=float32)
# Tensor("Mean_585:0", shape=(), dtype=float32)
# Tensor("Mean_586:0", shape=(), dtype=float32)
# Tensor("Mean_587:0", shape=(), dtype=float32)
# Tensor("Mean_588:0", shape=(), dtype=float32)
# Tensor("Mean_589:0", shape=(), dtype=float32)
# Tensor("Mean_590:0", shape=(), dtype=float32)
# Tensor("Mean_591:0", shape=(), dtype=float32)
# Tensor("Mean_592:0", shape=(), dtype=float32)
# Tensor("Mean_593:0", shape=(), dtype=float32)
# Tensor("Mean_594:0", shape=(), dtype=float32)
# Tensor("Mean_595:0", shape=(), dtype=float32)
# Tensor("Mean_596:0", shape=(), dtype=float32)
# Tensor("Mean_597:0", shape=(), dtype=float32)
# Tensor("Mean_598:0", shape=(), dtype=float32)
# Tensor("Mean_599:0", shape=(), dtype=float32)
# Tensor("Mean_600:0", shape=(), dtype=float32)
# Tensor("Mean_601:0", shape=(), dtype=float32)
# Tensor("Mean_602:0", shape=(), dtype=float32)
# Tensor("Mean_603:0", shape=(), dtype=float32)
# Tensor("Mean_604:0", shape=(), dtype=float32)
# Tensor("Mean_605:0", shape=(), dtype=float32)
# Tensor("Mean_606:0", shape=(), dtype=float32)
# Tensor("Mean_607:0", shape=(), dtype=float32)
# Tensor("Mean_608:0", shape=(), dtype=float32)
# Tensor("Mean_609:0", shape=(), dtype=float32)
# Tensor("Mean_610:0", shape=(), dtype=float32)
# Tensor("Mean_611:0", shape=(), dtype=float32)
# Tensor("Mean_612:0", shape=(), dtype=float32)
# Tensor("Mean_613:0", shape=(), dtype=float32)
# Tensor("Mean_614:0", shape=(), dtype=float32)
# Tensor("Mean_615:0", shape=(), dtype=float32)
# Tensor("Mean_616:0", shape=(), dtype=float32)
# Tensor("Mean_617:0", shape=(), dtype=float32)
# Tensor("Mean_618:0", shape=(), dtype=float32)
# Tensor("Mean_619:0", shape=(), dtype=float32)
# Tensor("Mean_620:0", shape=(), dtype=float32)
# Tensor("Mean_621:0", shape=(), dtype=float32)
# Tensor("Mean_622:0", shape=(), dtype=float32)
# Tensor("Mean_623:0", shape=(), dtype=float32)
# Tensor("Mean_624:0", shape=(), dtype=float32)
# Tensor("Mean_625:0", shape=(), dtype=float32)
# Tensor("Mean_626:0", shape=(), dtype=float32)
# Tensor("Mean_627:0", shape=(), dtype=float32)
# Tensor("Mean_628:0", shape=(), dtype=float32)
# Tensor("Mean_629:0", shape=(), dtype=float32)
# Tensor("Mean_630:0", shape=(), dtype=float32)
# Tensor("Mean_631:0", shape=(), dtype=float32)
# Tensor("Mean_632:0", shape=(), dtype=float32)
# Tensor("Mean_633:0", shape=(), dtype=float32)
# Tensor("Mean_634:0", shape=(), dtype=float32)
# Tensor("Mean_635:0", shape=(), dtype=float32)
# Tensor("Mean_636:0", shape=(), dtype=float32)
# Tensor("Mean_637:0", shape=(), dtype=float32)
# Tensor("Mean_638:0", shape=(), dtype=float32)
# Tensor("Mean_639:0", shape=(), dtype=float32)
# Tensor("Mean_640:0", shape=(), dtype=float32)
# Tensor("Mean_641:0", shape=(), dtype=float32)
# Tensor("Mean_642:0", shape=(), dtype=float32)
# Tensor("Mean_643:0", shape=(), dtype=float32)
# Tensor("Mean_644:0", shape=(), dtype=float32)
# Tensor("Mean_645:0", shape=(), dtype=float32)
# Tensor("Mean_646:0", shape=(), dtype=float32)
# Tensor("Mean_647:0", shape=(), dtype=float32)
# Tensor("Mean_648:0", shape=(), dtype=float32)
# Tensor("Mean_649:0", shape=(), dtype=float32)
# Tensor("Mean_650:0", shape=(), dtype=float32)
# Tensor("Mean_651:0", shape=(), dtype=float32)
# Tensor("Mean_652:0", shape=(), dtype=float32)
# Tensor("Mean_653:0", shape=(), dtype=float32)
# Tensor("Mean_654:0", shape=(), dtype=float32)
# Tensor("Mean_655:0", shape=(), dtype=float32)
# Tensor("Mean_656:0", shape=(), dtype=float32)
# Tensor("Mean_657:0", shape=(), dtype=float32)
# Tensor("Mean_658:0", shape=(), dtype=float32)
# Tensor("Mean_659:0", shape=(), dtype=float32)
# Tensor("Mean_660:0", shape=(), dtype=float32)
# Tensor("Mean_661:0", shape=(), dtype=float32)
# Tensor("Mean_662:0", shape=(), dtype=float32)
# Tensor("Mean_663:0", shape=(), dtype=float32)
# Tensor("Mean_664:0", shape=(), dtype=float32)
# Tensor("Mean_665:0", shape=(), dtype=float32)
# Tensor("Mean_666:0", shape=(), dtype=float32)
# Tensor("Mean_667:0", shape=(), dtype=float32)
# Tensor("Mean_668:0", shape=(), dtype=float32)
# Tensor("Mean_669:0", shape=(), dtype=float32)
# Tensor("Mean_670:0", shape=(), dtype=float32)
# Tensor("Mean_671:0", shape=(), dtype=float32)
# Tensor("Mean_672:0", shape=(), dtype=float32)
# Tensor("Mean_673:0", shape=(), dtype=float32)
# Tensor("Mean_674:0", shape=(), dtype=float32)
# Tensor("Mean_675:0", shape=(), dtype=float32)
# Tensor("Mean_676:0", shape=(), dtype=float32)
# Tensor("Mean_677:0", shape=(), dtype=float32)
# Tensor("Mean_678:0", shape=(), dtype=float32)
# Tensor("Mean_679:0", shape=(), dtype=float32)
# Tensor("Mean_680:0", shape=(), dtype=float32)
# Tensor("Mean_681:0", shape=(), dtype=float32)
# Tensor("Mean_682:0", shape=(), dtype=float32)
# Tensor("Mean_683:0", shape=(), dtype=float32)
# Tensor("Mean_684:0", shape=(), dtype=float32)
# Tensor("Mean_685:0", shape=(), dtype=float32)
# Tensor("Mean_686:0", shape=(), dtype=float32)
# Tensor("Mean_687:0", shape=(), dtype=float32)
# Tensor("Mean_688:0", shape=(), dtype=float32)
# Tensor("Mean_689:0", shape=(), dtype=float32)
# Tensor("Mean_690:0", shape=(), dtype=float32)
# Tensor("Mean_691:0", shape=(), dtype=float32)
# Tensor("Mean_692:0", shape=(), dtype=float32)
# Tensor("Mean_693:0", shape=(), dtype=float32)
# Tensor("Mean_694:0", shape=(), dtype=float32)
# Tensor("Mean_695:0", shape=(), dtype=float32)
# Tensor("Mean_696:0", shape=(), dtype=float32)
# Tensor("Mean_697:0", shape=(), dtype=float32)
# Tensor("Mean_698:0", shape=(), dtype=float32)
# Tensor("Mean_699:0", shape=(), dtype=float32)
# Tensor("Mean_700:0", shape=(), dtype=float32)
# Tensor("Mean_701:0", shape=(), dtype=float32)
# Tensor("Mean_702:0", shape=(), dtype=float32)
# Tensor("Mean_703:0", shape=(), dtype=float32)
# Tensor("Mean_704:0", shape=(), dtype=float32)
# Tensor("Mean_705:0", shape=(), dtype=float32)
# Tensor("Mean_706:0", shape=(), dtype=float32)
# Tensor("Mean_707:0", shape=(), dtype=float32)
# Tensor("Mean_708:0", shape=(), dtype=float32)
# Tensor("Mean_709:0", shape=(), dtype=float32)
# Tensor("Mean_710:0", shape=(), dtype=float32)
# Tensor("Mean_711:0", shape=(), dtype=float32)
# Tensor("Mean_712:0", shape=(), dtype=float32)
# Tensor("Mean_713:0", shape=(), dtype=float32)
# Tensor("Mean_714:0", shape=(), dtype=float32)
# Tensor("Mean_715:0", shape=(), dtype=float32)
# Tensor("Mean_716:0", shape=(), dtype=float32)
# Tensor("Mean_717:0", shape=(), dtype=float32)
# Tensor("Mean_718:0", shape=(), dtype=float32)
# Tensor("Mean_719:0", shape=(), dtype=float32)
# Tensor("Mean_720:0", shape=(), dtype=float32)
# Tensor("Mean_721:0", shape=(), dtype=float32)
# Tensor("Mean_722:0", shape=(), dtype=float32)
# Tensor("Mean_723:0", shape=(), dtype=float32)
# Tensor("Mean_724:0", shape=(), dtype=float32)
# Tensor("Mean_725:0", shape=(), dtype=float32)
# Tensor("Mean_726:0", shape=(), dtype=float32)
# Tensor("Mean_727:0", shape=(), dtype=float32)
# Tensor("Mean_728:0", shape=(), dtype=float32)
# Tensor("Mean_729:0", shape=(), dtype=float32)
# Tensor("Mean_730:0", shape=(), dtype=float32)
# Tensor("Mean_731:0", shape=(), dtype=float32)
# Tensor("Mean_732:0", shape=(), dtype=float32)
# Tensor("Mean_733:0", shape=(), dtype=float32)
# Tensor("Mean_734:0", shape=(), dtype=float32)
# Tensor("Mean_735:0", shape=(), dtype=float32)
# Tensor("Mean_736:0", shape=(), dtype=float32)
# Tensor("Mean_737:0", shape=(), dtype=float32)
# Tensor("Mean_738:0", shape=(), dtype=float32)
# Tensor("Mean_739:0", shape=(), dtype=float32)
# Tensor("Mean_740:0", shape=(), dtype=float32)
# Tensor("Mean_741:0", shape=(), dtype=float32)
# Tensor("Mean_742:0", shape=(), dtype=float32)
# Tensor("Mean_743:0", shape=(), dtype=float32)
# Tensor("Mean_744:0", shape=(), dtype=float32)
# Tensor("Mean_745:0", shape=(), dtype=float32)
# Tensor("Mean_746:0", shape=(), dtype=float32)
# Tensor("Mean_747:0", shape=(), dtype=float32)
# Tensor("Mean_748:0", shape=(), dtype=float32)
# Tensor("Mean_749:0", shape=(), dtype=float32)
# Tensor("Mean_750:0", shape=(), dtype=float32)
# Tensor("Mean_751:0", shape=(), dtype=float32)
# Tensor("Mean_752:0", shape=(), dtype=float32)
# Tensor("Mean_753:0", shape=(), dtype=float32)
# Tensor("Mean_754:0", shape=(), dtype=float32)
# Tensor("Mean_755:0", shape=(), dtype=float32)
# Tensor("Mean_756:0", shape=(), dtype=float32)
# Tensor("Mean_757:0", shape=(), dtype=float32)
# Tensor("Mean_758:0", shape=(), dtype=float32)
# Tensor("Mean_759:0", shape=(), dtype=float32)
# Tensor("Mean_760:0", shape=(), dtype=float32)
# Tensor("Mean_761:0", shape=(), dtype=float32)
# Tensor("Mean_762:0", shape=(), dtype=float32)
# Tensor("Mean_763:0", shape=(), dtype=float32)
# Tensor("Mean_764:0", shape=(), dtype=float32)
# Tensor("Mean_765:0", shape=(), dtype=float32)
# Tensor("Mean_766:0", shape=(), dtype=float32)
# Tensor("Mean_767:0", shape=(), dtype=float32)
# Tensor("Mean_768:0", shape=(), dtype=float32)
# Tensor("Mean_769:0", shape=(), dtype=float32)
# Tensor("Mean_770:0", shape=(), dtype=float32)
# Tensor("Mean_771:0", shape=(), dtype=float32)
# Tensor("Mean_772:0", shape=(), dtype=float32)
# Tensor("Mean_773:0", shape=(), dtype=float32)
# Tensor("Mean_774:0", shape=(), dtype=float32)
# Tensor("Mean_775:0", shape=(), dtype=float32)
# Tensor("Mean_776:0", shape=(), dtype=float32)
# Tensor("Mean_777:0", shape=(), dtype=float32)
# Tensor("Mean_778:0", shape=(), dtype=float32)
# Tensor("Mean_779:0", shape=(), dtype=float32)
# Tensor("Mean_780:0", shape=(), dtype=float32)
# Tensor("Mean_781:0", shape=(), dtype=float32)
# Tensor("Mean_782:0", shape=(), dtype=float32)
# Tensor("Mean_783:0", shape=(), dtype=float32)
# Tensor("Mean_784:0", shape=(), dtype=float32)
# Tensor("Mean_785:0", shape=(), dtype=float32)
# Tensor("Mean_786:0", shape=(), dtype=float32)
# Tensor("Mean_787:0", shape=(), dtype=float32)
# Tensor("Mean_788:0", shape=(), dtype=float32)
# Tensor("Mean_789:0", shape=(), dtype=float32)
# Tensor("Mean_790:0", shape=(), dtype=float32)
# Tensor("Mean_791:0", shape=(), dtype=float32)
# Tensor("Mean_792:0", shape=(), dtype=float32)
# Tensor("Mean_793:0", shape=(), dtype=float32)
# Tensor("Mean_794:0", shape=(), dtype=float32)
# Tensor("Mean_795:0", shape=(), dtype=float32)
# Tensor("Mean_796:0", shape=(), dtype=float32)
# Tensor("Mean_797:0", shape=(), dtype=float32)
# Tensor("Mean_798:0", shape=(), dtype=float32)
# Tensor("Mean_799:0", shape=(), dtype=float32)
# Tensor("Mean_800:0", shape=(), dtype=float32)
# Tensor("Mean_801:0", shape=(), dtype=float32)
# Tensor("Mean_802:0", shape=(), dtype=float32)
# Tensor("Mean_803:0", shape=(), dtype=float32)
# Tensor("Mean_804:0", shape=(), dtype=float32)
# Tensor("Mean_805:0", shape=(), dtype=float32)
# Tensor("Mean_806:0", shape=(), dtype=float32)
# Tensor("Mean_807:0", shape=(), dtype=float32)
# Tensor("Mean_808:0", shape=(), dtype=float32)
# Tensor("Mean_809:0", shape=(), dtype=float32)
# Tensor("Mean_810:0", shape=(), dtype=float32)
# Tensor("Mean_811:0", shape=(), dtype=float32)
# Tensor("Mean_812:0", shape=(), dtype=float32)
# Tensor("Mean_813:0", shape=(), dtype=float32)
# Tensor("Mean_814:0", shape=(), dtype=float32)
# Tensor("Mean_815:0", shape=(), dtype=float32)
# Tensor("Mean_816:0", shape=(), dtype=float32)
# Tensor("Mean_817:0", shape=(), dtype=float32)
# Tensor("Mean_818:0", shape=(), dtype=float32)
# Tensor("Mean_819:0", shape=(), dtype=float32)
# Tensor("Mean_820:0", shape=(), dtype=float32)
# Tensor("Mean_821:0", shape=(), dtype=float32)
# Tensor("Mean_822:0", shape=(), dtype=float32)
# Tensor("Mean_823:0", shape=(), dtype=float32)
# Tensor("Mean_824:0", shape=(), dtype=float32)
# Tensor("Mean_825:0", shape=(), dtype=float32)
# Tensor("Mean_826:0", shape=(), dtype=float32)
# Tensor("Mean_827:0", shape=(), dtype=float32)
# Tensor("Mean_828:0", shape=(), dtype=float32)
# Tensor("Mean_829:0", shape=(), dtype=float32)
# Tensor("Mean_830:0", shape=(), dtype=float32)
# Tensor("Mean_831:0", shape=(), dtype=float32)
# Tensor("Mean_832:0", shape=(), dtype=float32)
# Tensor("Mean_833:0", shape=(), dtype=float32)
# Tensor("Mean_834:0", shape=(), dtype=float32)
# Tensor("Mean_835:0", shape=(), dtype=float32)
# Tensor("Mean_836:0", shape=(), dtype=float32)
# Tensor("Mean_837:0", shape=(), dtype=float32)
# Tensor("Mean_838:0", shape=(), dtype=float32)
# Tensor("Mean_839:0", shape=(), dtype=float32)
# Tensor("Mean_840:0", shape=(), dtype=float32)
# Tensor("Mean_841:0", shape=(), dtype=float32)
# Tensor("Mean_842:0", shape=(), dtype=float32)
# Tensor("Mean_843:0", shape=(), dtype=float32)
# Tensor("Mean_844:0", shape=(), dtype=float32)
# Tensor("Mean_845:0", shape=(), dtype=float32)
# Tensor("Mean_846:0", shape=(), dtype=float32)
# Tensor("Mean_847:0", shape=(), dtype=float32)
# Tensor("Mean_848:0", shape=(), dtype=float32)
# Tensor("Mean_849:0", shape=(), dtype=float32)
# Tensor("Mean_850:0", shape=(), dtype=float32)
# Tensor("Mean_851:0", shape=(), dtype=float32)
# Tensor("Mean_852:0", shape=(), dtype=float32)
# Tensor("Mean_853:0", shape=(), dtype=float32)
# Tensor("Mean_854:0", shape=(), dtype=float32)
# Tensor("Mean_855:0", shape=(), dtype=float32)
# Tensor("Mean_856:0", shape=(), dtype=float32)
# Tensor("Mean_857:0", shape=(), dtype=float32)
# Tensor("Mean_858:0", shape=(), dtype=float32)
# Tensor("Mean_859:0", shape=(), dtype=float32)
# Tensor("Mean_860:0", shape=(), dtype=float32)
# Tensor("Mean_861:0", shape=(), dtype=float32)
# Tensor("Mean_862:0", shape=(), dtype=float32)
# Tensor("Mean_863:0", shape=(), dtype=float32)
# Tensor("Mean_864:0", shape=(), dtype=float32)
# Tensor("Mean_865:0", shape=(), dtype=float32)
# Tensor("Mean_866:0", shape=(), dtype=float32)
# Tensor("Mean_867:0", shape=(), dtype=float32)
# Tensor("Mean_868:0", shape=(), dtype=float32)
# Tensor("Mean_869:0", shape=(), dtype=float32)
# Tensor("Mean_870:0", shape=(), dtype=float32)
# Tensor("Mean_871:0", shape=(), dtype=float32)
# Tensor("Mean_872:0", shape=(), dtype=float32)
# Tensor("Mean_873:0", shape=(), dtype=float32)
# Tensor("Mean_874:0", shape=(), dtype=float32)
# Tensor("Mean_875:0", shape=(), dtype=float32)
# Tensor("Mean_876:0", shape=(), dtype=float32)
# Tensor("Mean_877:0", shape=(), dtype=float32)
# Tensor("Mean_878:0", shape=(), dtype=float32)
# Tensor("Mean_879:0", shape=(), dtype=float32)
# Tensor("Mean_880:0", shape=(), dtype=float32)
# Tensor("Mean_881:0", shape=(), dtype=float32)
# Tensor("Mean_882:0", shape=(), dtype=float32)
# Tensor("Mean_883:0", shape=(), dtype=float32)
# Tensor("Mean_884:0", shape=(), dtype=float32)
# Tensor("Mean_885:0", shape=(), dtype=float32)
# Tensor("Mean_886:0", shape=(), dtype=float32)
# Tensor("Mean_887:0", shape=(), dtype=float32)
# Tensor("Mean_888:0", shape=(), dtype=float32)
# Tensor("Mean_889:0", shape=(), dtype=float32)
# Tensor("Mean_890:0", shape=(), dtype=float32)
# Tensor("Mean_891:0", shape=(), dtype=float32)
# Tensor("Mean_892:0", shape=(), dtype=float32)
# Tensor("Mean_893:0", shape=(), dtype=float32)
# Tensor("Mean_894:0", shape=(), dtype=float32)
# Tensor("Mean_895:0", shape=(), dtype=float32)
# Tensor("Mean_896:0", shape=(), dtype=float32)
# Tensor("Mean_897:0", shape=(), dtype=float32)
# Tensor("Mean_898:0", shape=(), dtype=float32)
# Tensor("Mean_899:0", shape=(), dtype=float32)
# Tensor("Mean_900:0", shape=(), dtype=float32)
# Tensor("Mean_901:0", shape=(), dtype=float32)
# Tensor("Mean_902:0", shape=(), dtype=float32)
# Tensor("Mean_903:0", shape=(), dtype=float32)
# Tensor("Mean_904:0", shape=(), dtype=float32)
# Tensor("Mean_905:0", shape=(), dtype=float32)
# Tensor("Mean_906:0", shape=(), dtype=float32)
# Tensor("Mean_907:0", shape=(), dtype=float32)
# Tensor("Mean_908:0", shape=(), dtype=float32)
# Tensor("Mean_909:0", shape=(), dtype=float32)
# Tensor("Mean_910:0", shape=(), dtype=float32)
# Tensor("Mean_911:0", shape=(), dtype=float32)
# Tensor("Mean_912:0", shape=(), dtype=float32)
# Tensor("Mean_913:0", shape=(), dtype=float32)
# Tensor("Mean_914:0", shape=(), dtype=float32)
# Tensor("Mean_915:0", shape=(), dtype=float32)
# Tensor("Mean_916:0", shape=(), dtype=float32)
# Tensor("Mean_917:0", shape=(), dtype=float32)
# Tensor("Mean_918:0", shape=(), dtype=float32)
# Tensor("Mean_919:0", shape=(), dtype=float32)
# Tensor("Mean_920:0", shape=(), dtype=float32)
# Tensor("Mean_921:0", shape=(), dtype=float32)
# Tensor("Mean_922:0", shape=(), dtype=float32)
# Tensor("Mean_923:0", shape=(), dtype=float32)
# Tensor("Mean_924:0", shape=(), dtype=float32)
# Tensor("Mean_925:0", shape=(), dtype=float32)
# Tensor("Mean_926:0", shape=(), dtype=float32)
# Tensor("Mean_927:0", shape=(), dtype=float32)
# Tensor("Mean_928:0", shape=(), dtype=float32)
# Tensor("Mean_929:0", shape=(), dtype=float32)
# Tensor("Mean_930:0", shape=(), dtype=float32)
# Tensor("Mean_931:0", shape=(), dtype=float32)
# Tensor("Mean_932:0", shape=(), dtype=float32)
# Tensor("Mean_933:0", shape=(), dtype=float32)
# Tensor("Mean_934:0", shape=(), dtype=float32)
# Tensor("Mean_935:0", shape=(), dtype=float32)
# Tensor("Mean_936:0", shape=(), dtype=float32)
# Tensor("Mean_937:0", shape=(), dtype=float32)
# Tensor("Mean_938:0", shape=(), dtype=float32)
# Tensor("Mean_939:0", shape=(), dtype=float32)
# Tensor("Mean_940:0", shape=(), dtype=float32)
# Tensor("Mean_941:0", shape=(), dtype=float32)
# Tensor("Mean_942:0", shape=(), dtype=float32)
# Tensor("Mean_943:0", shape=(), dtype=float32)
# Tensor("Mean_944:0", shape=(), dtype=float32)
# Tensor("Mean_945:0", shape=(), dtype=float32)
# Tensor("Mean_946:0", shape=(), dtype=float32)
# Tensor("Mean_947:0", shape=(), dtype=float32)
# Tensor("Mean_948:0", shape=(), dtype=float32)
# Tensor("Mean_949:0", shape=(), dtype=float32)
# Tensor("Mean_950:0", shape=(), dtype=float32)
# Tensor("Mean_951:0", shape=(), dtype=float32)
# Tensor("Mean_952:0", shape=(), dtype=float32)
# Tensor("Mean_953:0", shape=(), dtype=float32)
# Tensor("Mean_954:0", shape=(), dtype=float32)
# Tensor("Mean_955:0", shape=(), dtype=float32)
# Tensor("Mean_956:0", shape=(), dtype=float32)
# Tensor("Mean_957:0", shape=(), dtype=float32)
# Tensor("Mean_958:0", shape=(), dtype=float32)
# Tensor("Mean_959:0", shape=(), dtype=float32)
# Tensor("Mean_960:0", shape=(), dtype=float32)
# Tensor("Mean_961:0", shape=(), dtype=float32)
# Tensor("Mean_962:0", shape=(), dtype=float32)
# Tensor("Mean_963:0", shape=(), dtype=float32)
# Tensor("Mean_964:0", shape=(), dtype=float32)
# Tensor("Mean_965:0", shape=(), dtype=float32)
# Tensor("Mean_966:0", shape=(), dtype=float32)
# Tensor("Mean_967:0", shape=(), dtype=float32)
# Tensor("Mean_968:0", shape=(), dtype=float32)
# Tensor("Mean_969:0", shape=(), dtype=float32)
# Tensor("Mean_970:0", shape=(), dtype=float32)
# Tensor("Mean_971:0", shape=(), dtype=float32)
# Tensor("Mean_972:0", shape=(), dtype=float32)
# Tensor("Mean_973:0", shape=(), dtype=float32)
# Tensor("Mean_974:0", shape=(), dtype=float32)
# Tensor("Mean_975:0", shape=(), dtype=float32)
# Tensor("Mean_976:0", shape=(), dtype=float32)
# Tensor("Mean_977:0", shape=(), dtype=float32)
# Tensor("Mean_978:0", shape=(), dtype=float32)
# Tensor("Mean_979:0", shape=(), dtype=float32)
# Tensor("Mean_980:0", shape=(), dtype=float32)
# Tensor("Mean_981:0", shape=(), dtype=float32)
# Tensor("Mean_982:0", shape=(), dtype=float32)
# Tensor("Mean_983:0", shape=(), dtype=float32)
# Tensor("Mean_984:0", shape=(), dtype=float32)
# Tensor("Mean_985:0", shape=(), dtype=float32)
# Tensor("Mean_986:0", shape=(), dtype=float32)
# Tensor("Mean_987:0", shape=(), dtype=float32)
# Tensor("Mean_988:0", shape=(), dtype=float32)
# Tensor("Mean_989:0", shape=(), dtype=float32)
# Tensor("Mean_990:0", shape=(), dtype=float32)
# Tensor("Mean_991:0", shape=(), dtype=float32)
# Tensor("Mean_992:0", shape=(), dtype=float32)
# Tensor("Mean_993:0", shape=(), dtype=float32)
# Tensor("Mean_994:0", shape=(), dtype=float32)
# Tensor("Mean_995:0", shape=(), dtype=float32)
# Tensor("Mean_996:0", shape=(), dtype=float32)
# Tensor("Mean_997:0", shape=(), dtype=float32)
# Tensor("Mean_998:0", shape=(), dtype=float32)
# Tensor("Mean_999:0", shape=(), dtype=float32)
